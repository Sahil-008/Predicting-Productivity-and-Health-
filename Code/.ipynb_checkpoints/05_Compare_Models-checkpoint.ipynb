# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split

# %%
metrics = pd.read_csv('D:/Predictive_deploy/results/model_metrics.csv')
print(metrics)
# Out:
#                         model       auc  precision    recall        f1
# 0               Linear_Scaled  0.591594   0.790598  0.192909  0.310142
# 1            Logistic_noSMOTE  0.827658   0.473559  0.831074  0.603331
# 2              Logistic_SMOTE  0.767953   0.538596  0.640250  0.585040
# 3                   XGB_SMOTE  0.902579   0.619590  0.567258  0.592270
# 4                    LightGBM  0.906421   0.638725  0.564129  0.599114
# 5  Random_Forest(classWeight)  0.816614   0.507148  0.776851  0.613674
# 6        Random_Forest(Smote)  0.816614   0.507148  0.776851  0.613674

# %%
df = pd.read_csv(r"D:\Predictive_deploy\model_ready.csv")

# %%
X = df.drop(columns=['is_productive','is_healthy'], errors='ignore')
y = df['is_productive']

# %%
X_train, X_val, y_train, y_val = train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)

# %%
import joblib

# %%
lr_model = joblib.load(r"D:\Predictive_deploy\models\logreg_sm.pkl")

rf_model = joblib.load(r"D:\Predictive_deploy\models\rf_smote.pkl")

xgb_model =joblib.load(r"D:\Predictive_deploy\models\xgb_smote.pkl")

Lgbm_model  = joblib.load(r"D:\Predictive_deploy\models\lgbm_smote.pkl")
print(type(Lgbm_model))
# Out:
# <class 'lightgbm.sklearn.LGBMClassifier'>

# %%
model_probs = {
    'Logistic Regression' : lr_model.predict_proba(X_val)[:,1],
    'Random Forest': rf_model.predict_proba(X_val)[:,1],
    'XGBoost': xgb_model.predict_proba(X_val)[:,1],
    'Light_GBM': Lgbm_model.predict_proba(X_val)[:,1]
}

plt.figure(figsize=(8,6))

for model_name, probs in model_probs.items():
    fpr, tpr, _ = roc_curve(y_val, probs)
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{model_name} (AUC = {roc_auc:.3f})")

plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:458: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
# Simple bar chart of AUC
plt.figure(figsize=(8,4))
metrics = metrics.sort_values('auc', ascending=False)
plt.bar(metrics['model'], metrics['auc'])
plt.xticks(rotation=45)
plt.title('Model AUC Comparison')
plt.show()

# %%
# Print best model
best = metrics.sort_values('auc', ascending=False).iloc[0]
print('Best model by AUC:', best['model'], 'AUC:', best['auc'])
# Out:
# Best model by AUC: LightGBM AUC: 0.906421153
